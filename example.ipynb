# %% [markdown]
# # Grok-Sentiment Example Notebook\n\nDemo of using grok_sentiment.py for text analysis. Run this in Jupyter or Colab after installing deps.

# %%
# Install if needed (uncomment)\n#!pip install transformers torch\n\nfrom grok_sentiment import get_sentiment_score

# %%
# Positive example\ntext = "Stocks are booming today!"\nscore = get_sentiment_score(text)\nprint(f"Score: {score:.2f}")  # ~0.95

# %%
# Negative example\ntext = "Market crashes hard."\nscore = get_sentiment_score(text)\nprint(f"Score: {score:.2f}")  # ~-0.98

# %%
# Neutral example\ntext = "The sky is blue."\nscore = get_sentiment_score(text)\nprint(f"Score: {score:.2f}")  # ~0.00

# %% [markdown]
# Fork and add your own examples! #Grok #xAI
